# %%
city = ("Delhi", 320000,36.5)
print(city[0])
print(city[1:3])
# Out:
# Delhi
# (320000, 36.5)

# %%
student ={
    "name" :"Berlin",
     "Age" : 20,
    "Course" : "B.Tech"
}

print(student["Age"])
print(student["Course"])
# Out:
# 20
# B.Tech

# %%
for key, value in student.items():
  print(key ,":",value)
# Out:
# name : Berlin
# Age : 20
# Course : B.Tech

# %%
all_keys= student.keys()
all_value= student.values()
print(all_keys)
print(all_value)
# Out:
# dict_keys(['name', 'Age', 'Course'])
# dict_values(['Berlin', 20, 'B.Tech'])

# %%
set1  = {1,2,3,4}
set2 = {3,4,5,6}
print()
print(set1 | set2 )
print(set1 & set2)
print(set1-set2)
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}

# %%
def total(*nums):
  print(sum(nums))
total(1,2,3,4)

def details(** data):
  for key ,value in data.items():
    print(f"[key]:[value]")
details(name = "Mohit",age =20)

def info(name, age):
  print(name,age)
info("Mohit" , 20)

# %%
def greet():
  print("Hello World !")
greet()

def add(a,b):
  print(a+b)
add(4,6)

def greet(name = "User"):
  print("Hello", name)
greet("Mohit")

def square(n):
  return n**2
square(9)
# Out:
# Hello World !
# 10
# Hello Mohit
# 81

# %%
menu_A = {"Pizza", "Burger", "Pasta", "Sandwich", "Coffee"}
menu_B = {"Burger", "Momos", "Pasta", "Tea", "Ice Cream"}
print(menu_A | menu_B)
print(menu_A & menu_B)
print(menu_A)
print(menu_B)
print(menu_A | menu_B)

# %%
import requests
latitude = 30.7076
longitude = 76.7151
url = f"https://api.open-meteo.com/v1/forecast?latitude={latitude}&longitude={longitude}&current_weather=true"
data = requests.get(url).json()
print(data["current_weather"]["temperature"])
print(data["current_weather"]["windspeed"])
print(data["current_weather"]["time"])

# %%
data = (10, 20, 30, 20, 40)
print(data.index(30))
print(data.index(40))
print(data.count(20))
print(data.count(10))
#we can't change tuples as they are immutable

# %%
sales = [25000, 32000, 56000, 67000, 12000]
print(sum(sales))
print(max(sales))
print(min(sales))
asc = sales
asc.sort()
print(asc)
desc= sales
desc.sort(reverse= True)
print(desc)
# Out:
# 192000
# 67000
# 12000
# [12000, 25000, 32000, 56000, 67000]
# [67000, 56000, 32000, 25000, 12000]
