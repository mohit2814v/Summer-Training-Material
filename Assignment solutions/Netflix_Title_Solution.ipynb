# %%
import pandas as pd
netflix=pd.read_csv('netflix_titles.csv')

# %%
print(netflix.head())
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
rows = netflix.shape[0]
cols = netflix.shape[1]

print("Rows:", rows)
print("Columns:", cols)
# Out:
# Rows: 8807
# Columns: 12

# %%
print(netflix.columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
print(netflix["type"].value_counts()["Movie"])
print(netflix["type"].value_counts()["TV Show"])
# Out:
# 6131
# 2676

# %%
print(netflix.loc[netflix["release_year"] > 2018, "title"])
# Out:
# 0              Dick Johnson Is Dead
# 1                     Blood & Water
# 2                         Ganglands
# 3             Jailbirds New Orleans
# 4                      Kota Factory
#                    ...
# 8516      The Spy Who Fell to Earth
# 8631    Trixie Mattel: Moving Parts
# 8718         Westside vs. the World
# 8752                       Wish Man
# 8756                      Woodstock
# Name: title, Length: 2575, dtype: object

# %%
netflix.sort_values("release_year", inplace= True, ascending=False)

# %%
print((netflix.isnull()).sum())
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
print(netflix["country"].nunique())
# Out:
# 748

# %%
print(netflix[netflix["type"]=="Movie"])
# Out:
#      show_id   type                                          title  \
# 68       s69  Movie                                     Schumacher
# 30       s31  Movie                                Ankahi Kahaniya
# 23       s24  Movie   Go! Go! Cory Carson: Chrissy Takes the Wheel
# 101     s102  Movie                         Untold: Breaking Point
# 64       s65  Movie                                     Nightbooks
# ...      ...    ...                                            ...
# 8763   s8764  Movie                WWII: Report from the Aleutians
# 8739   s8740  Movie             Why We Fight: The Battle of Russia
# 8660   s8661  Movie  Undercover: How to Operate Behind Enemy Lines
# 7790   s7791  Movie                                 Prelude to War
# 8205   s8206  Movie                           The Battle of Midway
#
#                                                director  \
# 68    Hanns-Bruno Kammertöns, Vanessa Nöcker, Michae...
# ...
